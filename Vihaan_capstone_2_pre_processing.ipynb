# %% [markdown]
# **Columns & Descriptions**
#
# Drive - Indicator of times ball has been possessed. Team does not matter
#
# qtr - Quarter
#
# down - Which down is being played
#
# TimeUnder - Minutes portioned into 16 intervals (0-15)
#
# TimeSecs - Total amount of seconds remaining, starting from 3600 (60 minutes)
#
# SideofField - Ball is either in offense's territory or defense's territory
#
# yrdln - which yardline ball is on at beginning of play, from 1-50
#
# yrdline100 - which yardline ball is on in respect to the whole field - 1-100
#
# ydstogo - Yards needed for a first down
#
# GoalToGo - Is the ball within the opoonent's 10 yard line? (Yes/No)
#
# FirstDown - Whether play resulted in a first down
#
# Offensiveteam - Offensive team
#
# DefensiveTeam - Defensive Team
#
# PlayAttempted - Whether play was attempted?
#
# Yards.Gained - Amount of yards gained
#
# Touchdown - Touchdown scored (Yes/No)
#
# PuntResult - Whether punt was clean or blocked
#
# PlayType - Type of play
#
# Passer - Who threw the ball
#
# PassAttempt - Was a pass attempted (Yes/No)
#
# PassOutcome - Complete or incomplete
#
# PassLength - Short or deep
#
# AirYards - Distance ball traveled in the air
#
# YardsAfterCatch - How many yards gained after ball was received
#
# QBHit - Was the quarterback hit on the play? (Not exclusively sacks)
#
# PassLocation - Left,right, middle
#
# InterceptionThrown - Was there an interception (Yes/No)
#
# Interceptor - Who intercepted the pass
#
# Rusher - Who ran the ball
#
# RushAttempt - Was it a rushing play (Yes/No)
#
# RunLocation - Left, right, middle
#
# RunGap - More specifically where the ball was rushed (end, tackle, guard)
#
# Receiver - Who caught the ball
#
# Reception - Was the ball caught?
#
# Returner - Which player returned the ball on a kickoff or punt
#
# Fumble - Was the ball fumbled (Yes/No)
#
# RecFumbTeam - Name of team that recovered the fumble
#
# RecFumbPlayer - Name of player that recovered the fumble
#
# Sack - Was there a sack (Yes/No)
#
# OffensiveTeamScore - Amount of total points for offensive team?
#
# DefensiveTeamScore - Amount of total points allowed for defensive team?
#
# ScoreDiff - Point differential
#
# AbsScoreDiff - Absolute value of ScoreDiff
#
# HomeTeam - Name of home team
#
# AwayTeam - Name of away team
#
# Timeout_Indicator - Was a timeout called on the play? (Yes/No)
#
# Season - Year of NFL season

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
sns.set()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# **Reading the data**

# %%
data=pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Fingertips training/Capstone_Project_2to.csv')
data.head()
# Out:
#          Date      GameID  Drive  qtr  ...       WPA    airWPA    yacWPA  Season
# 0  2009-09-10  2009091000      1    1  ...  0.060758       NaN       NaN    2009
# 1  2009-09-10  2009091000      1    1  ...  0.004655 -0.032244  0.036899    2009
# 2  2009-09-10  2009091000      1    1  ... -0.040295       NaN       NaN    2009
# 3  2009-09-10  2009091000      1    1  ... -0.049576  0.106663 -0.156239    2009
# 4  2009-09-10  2009091000      1    1  ...  0.097712       NaN       NaN    2009
#
# [5 rows x 102 columns]

# %%
list(data.columns.values)
# Out:
# ['Date',
#  'GameID',
#  'Drive',
#  'qtr',
#  'down',
#  'time',
#  'TimeUnder',
#  'TimeSecs',
#  'PlayTimeDiff',
#  'SideofField',
#  'yrdln',
#  'yrdline100',
#  'ydstogo',
#  'ydsnet',
#  'GoalToGo',
#  'FirstDown',
#  'posteam',
#  'DefensiveTeam',
#  'desc',
#  'PlayAttempted',
#  'Yards.Gained',
#  'sp',
#  'Touchdown',
#  'ExPointResult',
#  'TwoPointConv',
#  'DefTwoPoint',
#  'Safety',
#  'Onsidekick',
#  'PuntResult',
#  'PlayType',
#  'Passer',
#  'Passer_ID',
#  'PassAttempt',
#  'PassOutcome',
#  'PassLength',
#  'AirYards',
#  'YardsAfterCatch',
#  'QBHit',
#  'PassLocation',
#  'InterceptionThrown',
#  'Interceptor',
#  'Rusher',
#  'Rusher_ID',
#  'RushAttempt',
#  'RunLocation',
#  'RunGap',
#  'Receiver',
#  'Receiver_ID',
#  'Reception',
#  'ReturnResult',
#  'Returner',
#  'BlockingPlayer',
#  'Tackler1',
#  'Tackler2',
#  'FieldGoalResult',
#  'FieldGoalDistance',
#  'Fumble',
#  'RecFumbTeam',
#  'RecFumbPlayer',
#  'Sack',
#  'Challenge.Replay',
# ...

# %% [markdown]
# **Shape of data**

# %%
data.shape
# Out:
# (362447, 102)

# %% [markdown]
# **Basic Info of the dataset**

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 362447 entries, 0 to 362446
# Columns: 102 entries, Date to Season
# dtypes: float64(33), int64(31), object(38)
# memory usage: 282.1+ MB

# %% [markdown]
# **Stats of the dataset**

# %%
data.describe()
# Out:
#              GameID          Drive  ...         yacWPA         Season
# count  3.624470e+05  362447.000000  ...  141491.000000  362447.000000
# mean   2.012664e+09      12.347088  ...      -0.010492    2012.522071
# std    2.292258e+06       7.168173  ...       0.067972       2.290084
# min    2.009091e+09       1.000000  ...      -0.986673    2009.000000
# 25%    2.011091e+09       6.000000  ...      -0.018623    2011.000000
# 50%    2.013091e+09      12.000000  ...       0.000000    2013.000000
# 75%    2.015091e+09      18.000000  ...       0.011371    2015.000000
# max    2.017010e+09      35.000000  ...       1.000000    2016.000000
#
# [8 rows x 64 columns]

# %% [markdown]
# **Number of Unique values in every column.**

# %%
for a in data.columns:
  print(a,':',data[a].nunique())
# Out:
# Date : 376
# GameID : 2048
# Drive : 35
# qtr : 5
# down : 4
# time : 901
# TimeUnder : 16
# TimeSecs : 4329
# PlayTimeDiff : 155
# SideofField : 36
# yrdln : 50
# yrdline100 : 99
# ydstogo : 47
# ydsnet : 151
# GoalToGo : 2
# FirstDown : 2
# posteam : 34
# DefensiveTeam : 34
# desc : 335003
# PlayAttempted : 1
# Yards.Gained : 127
# sp : 2
# Touchdown : 2
# ExPointResult : 4
# TwoPointConv : 2
# DefTwoPoint : 2
# Safety : 2
# Onsidekick : 2
# PuntResult : 2
# PlayType : 15
# Passer : 330
# Passer_ID : 313
# PassAttempt : 2
# PassOutcome : 2
# PassLength : 3
# AirYards : 109
# YardsAfterCatch : 115
# QBHit : 2
# PassLocation : 3
# InterceptionThrown : 2
# Interceptor : 831
# Rusher : 1127
# Rusher_ID : 989
# RushAttempt : 2
# RunLocation : 3
# RunGap : 3
# Receiver : 1281
# Receiver_ID : 1376
# Reception : 2
# ReturnResult : 3
# Returner : 993
# BlockingPlayer : 92
# Tackler1 : 3360
# Tackler2 : 2256
# FieldGoalResult : 3
# FieldGoalDistance : 52
# Fumble : 2
# RecFumbTeam : 33
# ...

# %% [markdown]
# **How many missing data points we have:**

# %%
missing_values_count = data.isnull().sum()
total_cells = np.product(data.shape)
total_missing = missing_values_count.sum()
print((total_missing/total_cells) * 100,'%','total missing values')
# Out:
# 24.85847694188906 % total missing values

# %% [markdown]
# **Null values in each column**

# %%
pd.set_option('display.max_rows', 500)
data.isnull().sum()
# Out:
# Date                                0
# GameID                              0
# Drive                               0
# qtr                                 0
# down                            54218
# time                              188
# TimeUnder                           0
# TimeSecs                          188
# PlayTimeDiff                      374
# SideofField                       450
# yrdln                             723
# yrdline100                        723
# ydstogo                             0
# ydsnet                              0
# GoalToGo                          723
# FirstDown                       25597
# posteam                         21979
# DefensiveTeam                   21979
# desc                                2
# PlayAttempted                       0
# Yards.Gained                        0
# sp                                  0
# Touchdown                           0
# ExPointResult                  353399
# TwoPointConv                   361919
# ...

# %%
data.head(10)
# Out:
#          Date      GameID  Drive  qtr  ...       WPA    airWPA    yacWPA  Season
# 0  2009-09-10  2009091000      1    1  ...  0.060758       NaN       NaN    2009
# 1  2009-09-10  2009091000      1    1  ...  0.004655 -0.032244  0.036899    2009
# 2  2009-09-10  2009091000      1    1  ... -0.040295       NaN       NaN    2009
# 3  2009-09-10  2009091000      1    1  ... -0.049576  0.106663 -0.156239    2009
# 4  2009-09-10  2009091000      1    1  ...  0.097712       NaN       NaN    2009
# 5  2009-09-10  2009091000      2    1  ... -0.019524       NaN       NaN    2009
# 6  2009-09-10  2009091000      2    1  ... -0.004427 -0.010456  0.006029    2009
# 7  2009-09-10  2009091000      2    1  ... -0.034663       NaN       NaN    2009
# 8  2009-09-10  2009091000      2    1  ...  0.026054       NaN       NaN    2009
# 9  2009-09-10  2009091000      3    1  ... -0.006084 -0.024526  0.018442    2009
#
# [10 rows x 102 columns]

# %%
pd.set_option('display.max_rows', 500)
data.dtypes
# Out:
# Date                            object
# GameID                           int64
# Drive                            int64
# qtr                              int64
# down                           float64
# time                            object
# TimeUnder                        int64
# TimeSecs                       float64
# PlayTimeDiff                   float64
# SideofField                     object
# yrdln                          float64
# yrdline100                     float64
# ydstogo                          int64
# ydsnet                           int64
# GoalToGo                       float64
# FirstDown                      float64
# posteam                         object
# DefensiveTeam                   object
# desc                            object
# PlayAttempted                    int64
# Yards.Gained                     int64
# sp                               int64
# Touchdown                        int64
# ExPointResult                   object
# ...

# %% [markdown]
# **Dropping these col because they have 90% + null values. Does not make sense to fill the null values.**

# %%
df=data.drop(['ExPointResult','TwoPointConv','DefTwoPoint','PuntResult','ReturnResult','Returner','BlockingPlayer','Tackler2','FieldGoalResult','FieldGoalDistance'
,'ChalReplayResult','PenalizedTeam','PenaltyType','PenalizedPlayer'],axis=1)

# %%
df=df.drop(['Interceptor'],axis=1)

# %%
df.shape
# Out:
# (362447, 87)

# %%
pd.set_option('display.max_rows', 500)
df.isnull().sum()
# Out:
# Date                                0
# GameID                              0
# Drive                               0
# qtr                                 0
# down                            54218
# time                              188
# TimeUnder                           0
# TimeSecs                          188
# PlayTimeDiff                      374
# SideofField                       450
# yrdln                             723
# yrdline100                        723
# ydstogo                             0
# ydsnet                              0
# GoalToGo                          723
# FirstDown                       25597
# posteam                         21979
# DefensiveTeam                   21979
# desc                                2
# PlayAttempted                       0
# Yards.Gained                        0
# sp                                  0
# Touchdown                           0
# Safety                              0
# Onsidekick                          0
# ...

# %% [markdown]
# Replace 0 with no fumble for data visualization purpose

# %%
df1 = df.loc[df['Fumble'] == 0]
df2 = pd.concat([df, df1, df1]).drop_duplicates(keep=False)
df1['RecFumbTeam'] = df1['RecFumbTeam'].replace(np.nan,value="No Fumble")  
df1['RecFumbPlayer'] = df1['RecFumbPlayer'].replace(np.nan,value="No Fumble") 
df = pd.concat([df2, df1])
df.shape
# Out:
# (362447, 87)

# %% [markdown]
# Handling RecFumbPlayer and RecFumbTeam

# %%
df['RecFumbPlayer'] = df['RecFumbPlayer'].fillna(method="ffill")
df['RecFumbTeam'] = df['RecFumbTeam'].fillna(method="ffill")

# %% [markdown]
# Filling all the probablities value with 0

# %%
df.loc[:, 'EPA':'yacWPA'] = df.loc[:, 'EPA':'yacWPA'].fillna(0)
df.loc[:, 'EPA':'yacWPA'] = df.loc[:, 'EPA':'yacWPA'].fillna(method='ffill', axis=0).fillna(0)

# %% [markdown]
# Hanndling date and time

# %%
df['Date'] = pd.to_datetime(df['Date'])

# %%
df['time'] = df['time'].fillna(method="ffill")

# %%
df1 = df['time'].str.split(':', expand=True).astype(int)
df['new'] = df1[0] * 60 + df1[1]
df['new1'] = df['TimeUnder'] * 60

df['PlayTimeDiff'] = df['new1'] - df['new']

#Dropped Extra Columns
df.drop(columns = ['new1','new'],inplace=True)

# %% [markdown]
# Handling sideoffield, yrdln, yrdline100,goaltogo

# %%
df['SideofField'] = df['SideofField'].fillna(method="ffill")

# %%
df['yrdln'] = df['yrdln'].fillna(method="ffill")

# %%
df['yrdline100'] = df['yrdline100'].fillna(method="ffill")

# %%
df['GoalToGo'] = df['GoalToGo'].fillna(method="ffill")

# %%
df['Win_Prob'] = df['Win_Prob'].fillna(df['Home_WP_pre'])

# %%
df['ScoreDiff'] = df['PosTeamScore']- df['DefTeamScore']

# %%
df['AbsScoreDiff'] = -df['ScoreDiff']

# %% [markdown]
# Handling past outcome and first down

# %%
df['PassOutcome'] = df['PassOutcome'].fillna(method="ffill")

# %%
df['FirstDown'] = df['FirstDown'].fillna(method="ffill")

# %%
df.loc[:, 'No_Score_Prob':'ExpPts'] = df.loc[:, 'No_Score_Prob':'ExpPts'].fillna(0)
df.loc[:, 'No_Score_Prob':'ExpPts'] = df.loc[:, 'No_Score_Prob':'ExpPts'].fillna(method='ffill', axis=0).fillna(0)

# %% [markdown]
# Running a ffill loop in these columns

# %%
a = ['DefensiveTeam','posteam','DefTeamScore','PosTeamScore','ScoreDiff','AbsScoreDiff']
for i in a:
    df[i] = df[i].fillna(method="ffill")

# %%
def fill_cols_0(df, column):
    
    """There are also a few columns where the float 0.0 is suitable for missing values. This fucntion will
    fill these values.
    
    Parameters:
    
    df - dataframe to pull columns from
    
    column - can be a single column or list of columns"""
    
    df2 = df.copy()
    
    df2[column] = df2[column].fillna(0.0)
    
    return df2

# %%
df = fill_cols_0(df, ['down', 'TimeSecs', 'yrdln', 'yrdline100', 'FirstDown', 'PosTeamScore', 'DefTeamScore',
                 'ScoreDiff', 'AbsScoreDiff', 'GoalToGo'])

# %%
df.drop(columns = ['Passer','Tackler1','Receiver','Rusher'],inplace=True)

# %%
df['PassLength'] = df['PassLength'].fillna(method="ffill")

# %%
df['PassLocation'] = df['PassLocation'].fillna(method="ffill")

# %%
df['RunLocation'] = df['RunLocation'].fillna(method="ffill")
df['RunLocation'] = df['RunLocation'].fillna(method="bfill")

# %%
df['RunGap'] = df['RunGap'].fillna(method="ffill")
df['RunGap'] = df['RunGap'].fillna(method="bfill")

# %%
df['down'] = df['down'].fillna(method="ffill")

# %%
mode=df['desc'].mode()

# %%
df['desc'] = df['desc'].replace(np.nan,'mode')

# %%
pd.set_option('display.max_rows', 500)
df.isnull().sum()
# Out:
# Date                           0
# GameID                         0
# Drive                          0
# qtr                            0
# down                           0
# time                           0
# TimeUnder                      0
# TimeSecs                       0
# PlayTimeDiff                   0
# SideofField                    0
# yrdln                          0
# yrdline100                     0
# ydstogo                        0
# ydsnet                         0
# GoalToGo                       0
# FirstDown                      0
# posteam                        0
# DefensiveTeam                  0
# desc                           0
# PlayAttempted                  0
# Yards.Gained                   0
# sp                             0
# Touchdown                      0
# Safety                         0
# Onsidekick                     0
# PlayType                       0
# Passer_ID                      0
# PassAttempt                    0
# ...

# %%
df.shape
# Out:
# (362447, 83)

# %%
df.to_csv('capstone_2_final_preprocessed_data.csv')
# !cp capstone_2_final_preprocessed_data.csv "drive/My Drive/"
